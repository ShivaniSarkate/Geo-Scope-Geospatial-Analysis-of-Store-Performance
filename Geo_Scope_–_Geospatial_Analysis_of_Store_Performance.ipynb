# %% [markdown]
# **Project Title : GeoScope - Geospatial Analysis of Store Performance**

# %% [markdown]
# **Objective** : Visualize and analyze store performance across geographic regions to identify high-performing zones and expansion opportunities.

# %% [markdown]
# **Business Context** : A retail chain wants to understand how location affects store performance. Geospatial analysis helps uncover regional trends, delivery bottlenecks, and growth potential.

# %% [markdown]
# **Workflow Overview** :
# - Simulate store data with lat/lon and revenue
# - Plot store locations on a map
# - Create choropleth map of regional performance
# - Cluster stores by location and performance
# - Recommend strategic actions

# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster

# Step 2: Simulate store data
np.random.seed(42)
n = 50
df = pd.DataFrame({
    'StoreID': np.arange(n),
    'Latitude': np.random.uniform(19.0, 20.0, n),
    'Longitude': np.random.uniform(73.0, 74.0, n),
    'Revenue': np.random.normal(500000, 100000, n).astype(int)
})

# Step 3: Create map
m = folium.Map(location=[19.5, 73.5], zoom_start=8)
marker_cluster = MarkerCluster().add_to(m)

for i, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"Store {row['StoreID']}<br>Revenue: ₹{row['Revenue']:,}",
        icon=folium.Icon(color='green' if row['Revenue'] > 500000 else 'red')
    ).add_to(marker_cluster)

m  # This will render in Colab
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13fff2834e756579f2ace73c20cb69e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13fff2834e756579f2ace73c20cb69e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13fff2834e756579f2ace73c20cb69e0 = L.map(
#                 &quot;map_13fff2834e756579f2ace73c20cb69e0&quot;,
#                 {
#                     center: [19.5, 73.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8adb239803cf0b23ea7a688d1d218b48 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8adb239803cf0b23ea7a688d1d218b48.addTo(map_13fff2834e756579f2ace73c20cb69e0);
#
#
#             var marker_cluster_800c34c38c1cf10b8aa9e4caa5f3e785 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_fb071014c8c2febfe90d3773c5d64b39 = L.marker(
#                 [19.374540118847364, 73.96958462776456],
#                 {
# }
#             ).addTo(marker_cluster_800c34c38c1cf10b8aa9e4caa5f3e785);
#
#
#             var icon_0e4e837f989f08f56a61dc997e91d3c0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ae76131ee847bf4e541147418ab464c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75b2e30a06057c02118ba144ed918e18 = $(`&lt;div id=&quot;html_75b2e30a06057c02118ba144ed918e18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Store 0.0&lt;br&gt;Revenue: ₹508,704.0&lt;/div&gt;`)[0];
#                 popup_ae76131ee847bf4e541147418ab464c4.setContent(html_75b2e30a06057c02118ba144ed918e18);
#
#
#
#         marker_fb071014c8c2febfe90d3773c5d64b39.bindPopup(popup_ae76131ee847bf4e541147418ab464c4)
#         ;
#
#
#
#
#                 marker_fb071014c8c2febfe90d3773c5d64b39.setIcon(icon_0e4e837f989f08f56a61dc997e91d3c0);
#
#
#             var marker_96adb32885efaa00ea6e9008ea31c536 = L.marker(
#                 [19.950714306409917, 73.77513282336112],
#                 {
# }
#             ).addTo(marker_cluster_800c34c38c1cf10b8aa9e4caa5f3e785);
#
#
#             var icon_ecee118c07dd6a624257fbe74fc5e6f0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5a5b132cc16247d412b9686086695ba7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d37b494364ee1b8859c455e23579a200 = $(`&lt;div id=&quot;html_d37b494364ee1b8859c455e23579a200&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Store 1.0&lt;br&gt;Revenue: ₹470,099.0&lt;/div&gt;`)[0];
#                 popup_5a5b132cc16247d412b9686086695ba7.setContent(html_d37b494364ee1b8859c455e23579a200);
#
#
#
#         marker_96adb32885efaa00ea6e9008ea31c536.bindPopup(popup_5a5b132cc16247d412b9686086695ba7)
#         ;
#
#
#
#
#                 marker_96adb32885efaa00ea6e9008ea31c536.setIcon(icon_ecee118c07dd6a624257fbe74fc5e6f0);
#
#
#             var marker_6e1a25e7e008dd5f5946a72dfb7e6095 = L.marker(
#                 [19.731993941811407, 73.9394989415642],
#                 {
# }
#             ).addTo(marker_cluster_800c34c38c1cf10b8aa9e4caa5f3e785);
#
#
#             var icon_7b5339f1a96e9afd83c057984e0ed213 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_73c2bb52373c8e37678401603a50f2a5 = L.popu

# %% [markdown]
# **Executive Summary** :
# - **High-Performing Zone**: Western corridor near 19.8°N, 73.2°E
# - **Low-Performing Zone**: Eastern fringe with sparse density
# - **Recommendation**: Expand near high-revenue clusters; optimize delivery routes in low-performing zones
# - **Impact**: Location-aware decisions improve revenue and operational efficiency
